# %%
from sentence_transformers import SentenceTransformer,util
import numpy as np

# %%
model = SentenceTransformer('stsb-roberta-large')
model2 = SentenceTransformer('paraphrase-xlm-r-multilingual-v1')
model3 = SentenceTransformer('sentence-transformers/bert-base-nli-mean-tokens')

# %%
sentences1 = ['Due to internal crystal structure of the molecules.']  
sentences2 = ["nuclears theory  3D structure cube added or removed atoms",
    "Because of count of elements. Mostly about carbon dioxide.",
    "Allotrops such as diamond and graphit they have the same chemical composition but they have a different type of crystal structures.",
    "this name is izonom or isonome this caused from difference connection type of atoms and if is it dipol.",
    "because of elements energy and pyhsical features has different reaction for every composition.",
    "for example water  and ice. both materials are same chemical composition =H2O but physical features are compelety different.and there is bağ .and  this determine  ice or water but i couldnt remember.the diffrence is heat.",
    "Weather and temparature. Because fruit flies' genetics are easily effected affected by temparature and weather. ",
    "Chemical Structure.",
    "We call that allotropism. We may say diamond and grafit as an example.",
    "They are different physical features because same chemical's connection build can be different each other.",
    "We call it isomerism. In isomerism molecules that have the same numbers of the same kinds of atoms but differ in chemical and physical properties.",
    "Same chemical composition has different physical features because they have different crystal structure.",
    "isotopes, because they have same atomic number but has different electron numbers.",
    "Change of genetics. Function. dominant genetics and recessive genetics. blend of genetics.modificasion",
    "They called Allotropes. Allotropes are different crystal structures of the same element. Lavoiser showed that, he showed using diamonds and graphite. Burning diamonds and graphite produced the sam gas (CO2) (This was the first example of allotropism)",
    "For example graphit and diomond have pure Carbon(6) but they have different physical compound becasue in this case Carbon(6) can make 4 bond with other Carbon(6) atoms and it changes the physical features . So we can say that in compound , shape of bounding is matters.",
    "differences in their struct differences in their chemical connection",
    "because when atoms combined with each other their  composition is different for example if ""h=h and h-h"" their physical features will be different ",
    "Because the atomic weights and molecular weights of the compounds may be different. The bond types and bond numbers between atoms or molecules may be different.",
    "It might be from temparature. Or it might change by how much material we have. And the ratio between them.",
    "allotrophism. they have different structures. But they include same elements.",
    "Allotropes. They have same chemical composition but different physical features.",
    "It depends on bounds. Bounds depend on locations of elements and we call it allotropism.",
    "Because they have different allotrops which is changes the physical features. For example coil and diamond.",
    "Difference in activation energy in a chemical composition can change the compound in the result. For example: we can burn carbon to gain CO (Carbon monoxide) or to gain CO2 (Carbon dioxide) if we give to the reaction different amount of activation energy we can gain one of them.",
    "When the atom joined, then it lose own properties. So  its characteristic property change. Actually it looks same physcial property but chemical property is different.",
    "Because atoms are in different places and they have different bonds.",
    "Allotrops.",
    "Atoms of the same element are alike( I mean they are also different but has something in common ), but atoms of each element different one from the other in size and weight.",
    " ",
    "When the elements joined,the atoms lose their charachteristic proporties.",
    "Molecular bonds are covalent and ionic lead to different pyhsical properties. Different weight , structure and can oxcid.(I mean oksitlenebilme in Turkish). ",
    "The way that atoms are bonded are different. For example diamond and graphite has the same chemical composition but they have different properities. They are different structures of the same element and it is called allotropy.",
    "Allotropism. Difference in diziliş. Difference in molecular shape of the matter. Like coal and diamond. Those two are only carbons. But their molecular shapes are different.",
    "Allotropism.Its a different crystal structure of an element.An example coal and diamond.They are both made by carbon atoms but their crystal structure is different.So their physical features is different. The heat and pressure on coal turning this coal into diamond, and it takes so much time.",
    " ",
    "Because elements should behave of differences.And their weight are should be different.The radioactive is change their characteristic.Every elements feature are difference from others.",
    "Shape, molecular built, freezing point",
    "Like grafit and diamond. They made from carbon but have different physical apperences and when you burn them same gases out come. The reason is chemical bond differences . ",
    "Because they are in different area.(high,P,d)",
    "allotrophism (allotropism). Anthony lavoisier found and explain it. He burned diamound and carbon and he see same element carbon dioxid.Carbon and diamound released same gas.",
    "They are called allotropes. Their features change due to differences in their chemical structures.",
    "Chemical slecture and extends.",
    "They called allotrops. Their physical features was different because they can occure in different orans ( farklı oranlarda birleşebiliyorlar.) . (kimyasal bağları ve çekimleri yüzünden farklılar.)",
    "Distance between cells are different.",
    "If same chemical composition been in different place , these are going to behavior different. It is due to temperature , high from sea distance . I",
    "because of allotrope of elements",
    "Because elements can be make ionik or covalent band. If there are metal and nonmetal, they can be ionik band. If there are two nonmetal, they can be covalent  band. They could be izotop each other. Izotop is, in the same compositions proton counts are same but mass numbers are different.",
    "While working with diamond and graphite Lavoiser noticed that when burned them they released same type gases.(allotropism)Then lieb and Wöhler were about Two different compounds with same percentages of elements.this implies compounds have different arrangements for have different structurals. Because of the stereochemistry.İn a nutshell it is like this they have diiferent physical features because they different arrangement of atoms their 3D structure is different.  ",
    "Allotrop. they have the same atoms but  structure of atoms, their bonds is different each other.",
    "The element particuleses got bounds with different ways.",
    "This differences in the strecture make this. If the same chemical composition but different strecture its become different physical features. ",
    "diiference in chemical connecting type. it names is allotrop if there is chemicial composition but physical features of compounds are due to different it means they are allotrops.",
    "Difference is structure of atoms and arrengement of atoms. And also smell,taste can be different.",
    "Chemical composition and physical features are not connected each other.They just represent  each other.",
    "I think it says allotrop beacuse there arre some carbon but became different mate  it's about their connecting differences for example carbon has 4 connector sometimes it has 4 connects sometimes 2 times double connects so it makes mate different from each other. if it's not about allotrop. Maybe it is about during connecting time's air pressure or temparture differences beacuse they are effecting.",
    "Cells of plants and animals are almost the same, but physically very different from each other.",
    " alllogritms  is  same  chemical composittion but  different compounds because Carbon element is different order so    example diamong and grafiti",
    "Same chemical composition but different physical features of compounds are due to differences in isomerism. Its called Isomerism. Isomerism, the molecules that have same numbers of the same kinds of atoms but difference in chemical and physical properties. Energy are also is a factor in isomerism.",
    "It is called something like allotropes. It is due to differences in molecular structures.",
    "Some of chemical composition are similar but there are difference among their. When the elements are joined, the atoms lose their individual properties and have different properties from the elements they are composed of. A chemical formula is used a quick way to show the composition of compounds. Letters, numbers, and symbols are used to represent elements and the number of elements in each compound.",
    "Because of allotropism . We see that their chemical formulas are the same but their featuers are completly different.",
    "Same chemical composition but different physical features of compounds are due tou differences in period number. Elements which in the same group acts in a similar way as chemical composition. Because the number of atoms they have in the last orbital is same they have same chemical composition. But the total quantity of atoms they have is different so their atomic number is different and they have different physical features of compounds.",
    "Same chemical composition with different physical features gives different results",
    "covid (virus)",
    "allographics composition has different features of compounds for such as elmas and grafit. they have different arragement of atoms and they have different crystial structures. elmas and grafit is same chemical comporisiton but they have different arragment of atoms. so elmas is sert but grafit is yumuşak",
    "Due to bonds in-between. And bonds depends on temperature and shape.",
    "It is due to allotropy. Differences in either bound lines and thus the differences in 3D models of the elements changes the physical features of compounds.",
    "their atoms are attached eachother in different ways.",
    "This is allotropes , ı could not remember correct name of this.",
    "Chemical Structure. For example when we heat some certain compounds, we get a different compound. But they will share the same formula. What differs between those two compounds is their Chemical Structure.",
    "Allatrop . For example diamond and coal. Even though  they are both made of carbon they are totaly different.",
    "They are same in chemical but have differences in physical.They might have different bonds with same atoms which called polarity and dipolarity.",
    "Due to diffrences in how their crystal structures were bonded-made.(Allotropizm)",
    "İf it is the same chemical composition the type of the elements and the numbers of the elements on this composition is same so it depends only how they connected to themself",
    "Compounds by elemental analysis, color, crystal form, melting point, boiling point, taste, smell.",
    "this is called allotropism for example diamond and  k      .  its because of atoms order and any other species",
    "When the elements are joined, the atoms lose their individual properties and have different properties from the elements they are composed of. A chemical formula is used a quick way to show the composition of compounds. Letters, numbers, and symbols are used to represent elements and the number of elements in each compound.",
    "Because of the polarity and dipolarity. When we look at the geometry of compounds, we can see bonds and angles that makes the compound itself. Also different structures as well.",
    "they are due to differences in allotrops' s properties",
    "Chemical bonds cause these different physical features. Compositions may have same kind and many of elements but they might have different physical features. Different kinds of bonds and different bonding styles on same elements causes this differs.",
    "Allotropism. Allotrops have the same proposition in chemical reactions, but different physical features. For instance, graphit and diamond produced same gas (CO2). Lavoisier were explained allotrops first, as well.",
    "because this compounds have different location in space. like mirror or left hand right hand. Sometimes this compounds have different chemical bonds.",
    "due to differences are. ",
    "Due to stereo (3D) structure. It has same atoms but structure is different.",
    "Because their structures are different. The connection type between elements are different. So in spite of same chemical composition and same close formulation they are different.",
    "Allotropes are same chemical composition's different structed styles. For example carbon has two different physical shape because of the heat and force on carbon. If you put carbon in bottom of the down and wait too long it will be diamond. So time, force on it and heat are the most important things in this differences.",
    "isomerism, the existence of molecules that have the same numbers of the same kinds of atoms  hence the same formula but differences  in chemical and physical properties."]# encode list of sentences to get their embeddings
sentences1 = ['Due to internal crystal structure of the molecules.'] 
sentences2 = ["Same chemical composition has different physical features have different crystal structure."]
embedding1 = model3.encode(sentences2, convert_to_tensor=True)
embedding2 = model3.encode(sentences1, convert_to_tensor=True)# compute similarity scores of two embeddings
embedding11 = model.encode(sentences2, convert_to_tensor=True)
embedding22 = model.encode(sentences1, convert_to_tensor=True)# compute similarity scores of two embeddings
# compute similarity scores of two embeddings
#cosine_scores = util.pytorch_cos_sim(embedding1, embedding2)
# compute similarity scores of two embeddings
cosine_scores = util.pytorch_cos_sim(embedding1, embedding2)
print("bert")
for i in range(len(sentences1)):
    for j in range(len(sentences2)):
        print("Sentence 1:", sentences1[i])
        print("Sentence 2:", sentences2[j])
        print("Similarity Score:", cosine_scores[i][j].item())
        print()
cosine_scores2 = util.pytorch_cos_sim(embedding11, embedding22)
print("roberta")
for i in range(len(sentences1)):
    for j in range(len(sentences2)):
        print("Sentence 1:", sentences1[i])
        print("Sentence 2:", sentences2[j])
        print("Similarity Score:", cosine_scores2[i][j].item())
        print()
# Out:
# bert
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Same chemical composition has different physical features have different crystal structure.
# Similarity Score: 0.6225765943527222
#
# roberta
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Same chemical composition has different physical features have different crystal structure.
# Similarity Score: 0.6335620880126953

# %%
embedding11 = model2.encode(sentences1, convert_to_tensor=True)
embedding22 = model2.encode(sentences2, convert_to_tensor=True)
cosine_scores2 = util.pytorch_cos_sim(embedding11, embedding22)
print("model2")
for i in range(len(sentences1)):
    for j in range(len(sentences2)):
        print("Sentence 1:", sentences1[i])
        print("Sentence 2:", sentences2[j])
        print("Similarity Score:", cosine_scores2[i][j].item())
        print()
# Out:
# model2
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: nuclears theory  3D structure cube added or removed atoms
# Similarity Score: 0.40733397006988525
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because of count of elements. Mostly about carbon dioxide.
# Similarity Score: 0.4653233289718628
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Allotrops such as diamond and graphit they have the same chemical composition but they have a different type of crystal structures.
# Similarity Score: 0.48202383518218994
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: this name is izonom or isonome this caused from difference connection type of atoms and if is it dipol.
# Similarity Score: 0.42166101932525635
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: because of elements energy and pyhsical features has different reaction for every composition.
# Similarity Score: 0.38366344571113586
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: for example water  and ice. both materials are same chemical composition =H2O but physical features are compelety different.and there is bağ .and  this determine  ice or water but i couldnt remember.the diffrence is heat.
# Similarity Score: 0.33621013164520264
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Weather and temparature. Because fruit flies' genetics are easily effected affected by temparature and weather.
# Similarity Score: 0.2409549057483673
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Chemical Structure.
# Similarity Score: 0.5870275497436523
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: We call that allotropism. We may say diamond and grafit as an example.
# Similarity Score: 0.18530279397964478
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: They are different physical features because same chemical's connection build can be different each other.
# Similarity Score: 0.3234916031360626
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: We call it isomerism. In isomerism molecules that have the same numbers of the same kinds of atoms but differ in chemical and physical properties.
# Similarity Score: 0.41952937841415405
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Same chemical composition has different physical features because they have different crystal structure.
# Similarity Score: 0.5630972385406494
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: isotopes, because they have same atomic number but has different electron numbers.
# Similarity Score: 0.30802205204963684
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Change of genetics. Function. dominant genetics and recessive genetics. blend of genetics.modificasion
# Similarity Score: 0.33252841234207153
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: They called Allotropes. Allotropes are different crystal structures of the same element. Lavoiser showed that, he showed using diamonds and graphite. Burning diamonds and graphite produced the sam gas (CO2) (This was the first example of allotropism)
# Similarity Score: 0.34275537729263306
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: For example graphit and diomond have pure Carbon(6) but they have different physical compound becasue in this case Carbon(6) can make 4 bond with other Carbon(6) atoms and it changes the physical features . So we can say that in compound , shape of bounding is matters.
# Similarity Score: 0.41845738887786865
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: differences in their struct differences in their chemical connection
# Similarity Score: 0.41040199995040894
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: because when atoms combined with each other their  composition is different for example if h=h and h-h their physical features will be different
# Similarity Score: 0.3720741868019104
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because the atomic weights and molecular weights of the compounds may be different. The bond types and bond numbers between atoms or molecules may be different.
# Similarity Score: 0.44077733159065247
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: It might be from temparature. Or it might change by how much material we have. And the ratio between them.
# Similarity Score: 0.2918315529823303
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: allotrophism. they have different structures. But they include same elements.
# Similarity Score: 0.3044778108596802
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Allotropes. They have same chemical composition but different physical features.
# Similarity Score: 0.258456826210022
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: It depends on bounds. Bounds depend on locations of elements and we call it allotropism.
# Similarity Score: 0.3052126467227936
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because they have different allotrops which is changes the physical features. For example coil and diamond.
# Similarity Score: 0.3940162658691406
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Difference in activation energy in a chemical composition can change the compound in the result. For example: we can burn carbon to gain CO (Carbon monoxide) or to gain CO2 (Carbon dioxide) if we give to the reaction different amount of activation energy we can gain one of them.
# Similarity Score: 0.3380278944969177
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: When the atom joined, then it lose own properties. So  its characteristic property change. Actually it looks same physcial property but chemical property is different.
# Similarity Score: 0.4168233275413513
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because atoms are in different places and they have different bonds.
# Similarity Score: 0.4886326193809509
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Allotrops.
# Similarity Score: 0.2489151656627655
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Atoms of the same element are alike( I mean they are also different but has something in common ), but atoms of each element different one from the other in size and weight.
# Similarity Score: 0.2723183035850525
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2:
# Similarity Score: 0.23286710679531097
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: When the elements joined,the atoms lose their charachteristic proporties.
# Similarity Score: 0.48633265495300293
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Molecular bonds are covalent and ionic lead to different pyhsical properties. Different weight , structure and can oxcid.(I mean oksitlenebilme in Turkish).
# Similarity Score: 0.41820746660232544
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: The way that atoms are bonded are different. For example diamond and graphite has the same chemical composition but they have different properities. They are different structures of the same element and it is called allotropy.
# Similarity Score: 0.47629988193511963
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Allotropism. Difference in diziliş. Difference in molecular shape of the matter. Like coal and diamond. Those two are only carbons. But their molecular shapes are different.
# Similarity Score: 0.44926661252975464
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Allotropism.Its a different crystal structure of an element.An example coal and diamond.They are both made by carbon atoms but their crystal structure is different.So their physical features is different. The heat and pressure on coal turning this coal into diamond, and it takes so much time.
# Similarity Score: 0.4580279290676117
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2:
# Similarity Score: 0.23286710679531097
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because elements should behave of differences.And their weight are should be different.The radioactive is change their characteristic.Every elements feature are difference from others.
# Similarity Score: 0.28118056058883667
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Shape, molecular built, freezing point
# Similarity Score: 0.505591630935669
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Like grafit and diamond. They made from carbon but have different physical apperences and when you burn them same gases out come. The reason is chemical bond differences .
# Similarity Score: 0.3564780056476593
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because they are in different area.(high,P,d)
# Similarity Score: 0.2661564350128174
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: allotrophism (allotropism). Anthony lavoisier found and explain it. He burned diamound and carbon and he see same element carbon dioxid.Carbon and diamound released same gas.
# Similarity Score: 0.23719537258148193
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: They are called allotropes. Their features change due to differences in their chemical structures.
# Similarity Score: 0.3387499451637268
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Chemical slecture and extends.
# Similarity Score: 0.2934342622756958
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: They called allotrops. Their physical features was different because they can occure in different orans ( farklı oranlarda birleşebiliyorlar.) . (kimyasal bağları ve çekimleri yüzünden farklılar.)
# Similarity Score: 0.2618250846862793
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Distance between cells are different.
# Similarity Score: 0.3034325838088989
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: If same chemical composition been in different place , these are going to behavior different. It is due to temperature , high from sea distance . I
# Similarity Score: 0.3021399676799774
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: because of allotrope of elements
# Similarity Score: 0.45682841539382935
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because elements can be make ionik or covalent band. If there are metal and nonmetal, they can be ionik band. If there are two nonmetal, they can be covalent  band. They could be izotop each other. Izotop is, in the same compositions proton counts are same but mass numbers are different.
# Similarity Score: 0.2645488381385803
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: While working with diamond and graphite Lavoiser noticed that when burned them they released same type gases.(allotropism)Then lieb and Wöhler were about Two different compounds with same percentages of elements.this implies compounds have different arrangements for have different structurals. Because of the stereochemistry.İn a nutshell it is like this they have diiferent physical features because they different arrangement of atoms their 3D structure is different.
# Similarity Score: 0.5189268589019775
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Allotrop. they have the same atoms but  structure of atoms, their bonds is different each other.
# Similarity Score: 0.38668525218963623
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: The element particuleses got bounds with different ways.
# Similarity Score: 0.39698660373687744
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: This differences in the strecture make this. If the same chemical composition but different strecture its become different physical features.
# Similarity Score: 0.40328073501586914
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: diiference in chemical connecting type. it names is allotrop if there is chemicial composition but physical features of compounds are due to different it means they are allotrops.
# Similarity Score: 0.39592117071151733
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Difference is structure of atoms and arrengement of atoms. And also smell,taste can be different.
# Similarity Score: 0.3631232976913452
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Chemical composition and physical features are not connected each other.They just represent  each other.
# Similarity Score: 0.35127687454223633
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: I think it says allotrop beacuse there arre some carbon but became different mate  it's about their connecting differences for example carbon has 4 connector sometimes it has 4 connects sometimes 2 times double connects so it makes mate different from each other. if it's not about allotrop. Maybe it is about during connecting time's air pressure or temparture differences beacuse they are effecting.
# Similarity Score: 0.29464977979660034
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Cells of plants and animals are almost the same, but physically very different from each other.
# Similarity Score: 0.23346199095249176
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2:  alllogritms  is  same  chemical composittion but  different compounds because Carbon element is different order so    example diamong and grafiti
# Similarity Score: 0.40940749645233154
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Same chemical composition but different physical features of compounds are due to differences in isomerism. Its called Isomerism. Isomerism, the molecules that have same numbers of the same kinds of atoms but difference in chemical and physical properties. Energy are also is a factor in isomerism.
# Similarity Score: 0.39435648918151855
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: It is called something like allotropes. It is due to differences in molecular structures.
# Similarity Score: 0.44607484340667725
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Some of chemical composition are similar but there are difference among their. When the elements are joined, the atoms lose their individual properties and have different properties from the elements they are composed of. A chemical formula is used a quick way to show the composition of compounds. Letters, numbers, and symbols are used to represent elements and the number of elements in each compound.
# Similarity Score: 0.48395031690597534
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because of allotropism . We see that their chemical formulas are the same but their featuers are completly different.
# Similarity Score: 0.21669235825538635
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Same chemical composition but different physical features of compounds are due tou differences in period number. Elements which in the same group acts in a similar way as chemical composition. Because the number of atoms they have in the last orbital is same they have same chemical composition. But the total quantity of atoms they have is different so their atomic number is different and they have different physical features of compounds.
# Similarity Score: 0.42373162508010864
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Same chemical composition with different physical features gives different results
# Similarity Score: 0.3438373804092407
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: covid (virus)
# Similarity Score: 0.20608875155448914
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: allographics composition has different features of compounds for such as elmas and grafit. they have different arragement of atoms and they have different crystial structures. elmas and grafit is same chemical comporisiton but they have different arragment of atoms. so elmas is sert but grafit is yumuşak
# Similarity Score: 0.3870674967765808
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Due to bonds in-between. And bonds depends on temperature and shape.
# Similarity Score: 0.44158849120140076
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: It is due to allotropy. Differences in either bound lines and thus the differences in 3D models of the elements changes the physical features of compounds.
# Similarity Score: 0.49834972620010376
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: their atoms are attached eachother in different ways.
# Similarity Score: 0.45085740089416504
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: This is allotropes , ı could not remember correct name of this.
# Similarity Score: 0.1202528104186058
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Chemical Structure. For example when we heat some certain compounds, we get a different compound. But they will share the same formula. What differs between those two compounds is their Chemical Structure.
# Similarity Score: 0.45481377840042114
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Allatrop . For example diamond and coal. Even though  they are both made of carbon they are totaly different.
# Similarity Score: 0.2032412588596344
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: They are same in chemical but have differences in physical.They might have different bonds with same atoms which called polarity and dipolarity.
# Similarity Score: 0.354189932346344
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Due to diffrences in how their crystal structures were bonded-made.(Allotropizm)
# Similarity Score: 0.6607707738876343
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: İf it is the same chemical composition the type of the elements and the numbers of the elements on this composition is same so it depends only how they connected to themself
# Similarity Score: 0.421211302280426
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Compounds by elemental analysis, color, crystal form, melting point, boiling point, taste, smell.
# Similarity Score: 0.4433083236217499
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: this is called allotropism for example diamond and  k      .  its because of atoms order and any other species
# Similarity Score: 0.36301159858703613
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: When the elements are joined, the atoms lose their individual properties and have different properties from the elements they are composed of. A chemical formula is used a quick way to show the composition of compounds. Letters, numbers, and symbols are used to represent elements and the number of elements in each compound.
# Similarity Score: 0.5108859539031982
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because of the polarity and dipolarity. When we look at the geometry of compounds, we can see bonds and angles that makes the compound itself. Also different structures as well.
# Similarity Score: 0.502544641494751
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: they are due to differences in allotrops' s properties
# Similarity Score: 0.23732367157936096
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Chemical bonds cause these different physical features. Compositions may have same kind and many of elements but they might have different physical features. Different kinds of bonds and different bonding styles on same elements causes this differs.
# Similarity Score: 0.3961440920829773
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Allotropism. Allotrops have the same proposition in chemical reactions, but different physical features. For instance, graphit and diamond produced same gas (CO2). Lavoisier were explained allotrops first, as well.
# Similarity Score: 0.2846534848213196
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: because this compounds have different location in space. like mirror or left hand right hand. Sometimes this compounds have different chemical bonds.
# Similarity Score: 0.4698939025402069
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: due to differences are.
# Similarity Score: 0.31790071725845337
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Due to stereo (3D) structure. It has same atoms but structure is different.
# Similarity Score: 0.5507428646087646
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Because their structures are different. The connection type between elements are different. So in spite of same chemical composition and same close formulation they are different.
# Similarity Score: 0.4588104486465454
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: Allotropes are same chemical composition's different structed styles. For example carbon has two different physical shape because of the heat and force on carbon. If you put carbon in bottom of the down and wait too long it will be diamond. So time, force on it and heat are the most important things in this differences.
# Similarity Score: 0.42155739665031433
#
# Sentence 1: Due to internal crystal structure of the molecules.
# Sentence 2: isomerism, the existence of molecules that have the same numbers of the same kinds of atoms  hence the same formula but differences  in chemical and physical properties.
# Similarity Score: 0.5074342489242554
